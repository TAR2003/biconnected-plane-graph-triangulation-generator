# %% [markdown]
# # Graph Triangulation: Time Complexity Benchmarking
#
# ---
#
# ## Overview
#
# This notebook runs comprehensive time complexity benchmarking for the **Biconnected Graph Triangulation Algorithm**. The benchmark suite tests the algorithm's performance against various graph configurations and sizes.
#
# All code, test cases, and results are sourced directly from the GitHub repository: **[TAR2003/Thesis](https://github.com/TAR2003/Thesis)**
#
# ---

# %% [markdown]
# ## 1. Environment Setup
#
# ---
#
# Initialize the Python environment and import required libraries for benchmarking and analysis.

# %%
import os
import sys
import subprocess
import json
from pathlib import Path
from datetime import datetime

# %% [markdown]
# ## 2. Repository Setup
#
# ---
#
# ### Step 1: Configure Working Directories
#
# We'll set up the working directory paths and determine if the Thesis repository needs to be cloned from GitHub.

# %%
working_dir = "/kaggle/working"
thesis_dir = os.path.join(working_dir, "Thesis")
time_complexity_dir = os.path.join(thesis_dir, "time_complexity")

print("🔧 Configuring Working Directories")
print("=" * 70)
print(f"Working directory: {working_dir}")
print(f"Thesis directory: {thesis_dir}")
print(f"Target directory: {time_complexity_dir}")
print("=" * 70)
# Out:
# 🔧 Configuring Working Directories
# ======================================================================
# Working directory: /kaggle/working
# Thesis directory: /kaggle/working/Thesis
# Target directory: /kaggle/working/Thesis/time_complexity
# ======================================================================

# %% [markdown]
# ### Step 2: Check if Thesis Repository Exists
#
# We'll check if the Thesis folder is already available. If it exists, we'll skip cloning. If not, we'll proceed to clone from GitHub.

# %%
print("\n📁 Checking for Thesis Repository")
print("=" * 70)

if os.path.exists(thesis_dir):
    print(f"✓ Thesis folder already exists!")
    print(f"  Location: {thesis_dir}")
    thesis_exists = True
else:
    print(f"⏳ Thesis folder not found")
    print(f"  Expected location: {thesis_dir}")
    print(f"  → Will clone from GitHub: https://github.com/TAR2003/Thesis.git")
    thesis_exists = False

print("=" * 70)
# Out:
# 📁 Checking for Thesis Repository
# ======================================================================
# ⏳ Thesis folder not found
#   Expected location: /kaggle/working/Thesis
#   → Will clone from GitHub: https://github.com/TAR2003/Thesis.git
# ======================================================================

# %% [markdown]
# ---
#
# ## 🛰️ Step 3: Securely Cloning Private Repository
#
# To bridge the gap between your private GitHub research and the Kaggle environment, we use a **GitHub Fine-Grained Personal Access Token (PAT)**. This allows the Kaggle VM to authenticate securely without exposing your credentials or requiring interactive input.
#
# ### 🛡️ Security & Performance Highlights
# * **Kaggle Secrets:** We leverage `UserSecretsClient` to pull the token from encrypted storage, keeping your "key" invisible even if the notebook is shared.
# * **Authenticated Injection:** The token is injected directly into the HTTPS URL (`https://<TOKEN>@github.com/...`) for seamless non-interactive cloning.
# * **Shallow Clone (`--depth=1`):** Optimizes disk space and reduces download time by pulling only the latest snapshot, ignoring the bulky commit history.
# * **Fail-Safe Logic:** Includes a 5-minute `subprocess` timeout and comprehensive error handling to prevent the notebook from hanging.
#
# ---
#
# ### 🛠️ Execution Requirements
# | Requirement | Status | Action if Missing |
# | :--- | :--- | :--- |
# | **Kaggle Internet** | **Required** | Toggle **ON** in the right-hand Settings sidebar. |
# | **Kaggle Secret** | **Required** | Add via **Add-ons -> Secrets** with label `thesis-github-repo-secret`. |
# | **PAT Scope** | **Required** | Ensure token has **"Contents: Read"** access to the specific repo. |
#
# ---

# %%
from kaggle_secrets import UserSecretsClient
import subprocess
import os

# 1. Get the token from Kaggle Secrets
user_secrets = UserSecretsClient()
try:
    # Make sure this matches the Label you set in Kaggle Add-ons -> Secrets
    secret_value_0 = user_secrets.get_secret("thesis-github-repo-secret")
except Exception:
    print("✗ Could not find Kaggle Secret. Please check your Secret Label.")
    raise

# Define your repository details
github_user = "TAR2003"
repo_name = "Thesis"
# Inject the token into the URL for authentication
authenticated_url = f"https://{secret_value_0}@github.com/{github_user}/{repo_name}.git"

if not thesis_exists:
    print("\n🌐 Cloning Private Thesis Repository from GitHub")
    print("=" * 70)
    print(f"Repository: https://github.com/{github_user}/{repo_name}.git")
    print(f"Destination: {working_dir}")
    print("=" * 70)
    
    try:
        # Change to working directory first
        os.chdir(working_dir)
        print(f"✓ Changed to working directory: {os.getcwd()}\n")
        
        print("⏳ Cloning in progress (Private Access enabled)...\n")
        
        # Clone with verbose output to show progress
        # Note: We use the authenticated_url here
        result = subprocess.run(
            ["git", "clone", "--progress", "--depth=1", authenticated_url],
            capture_output=False,
            text=True,
            timeout=300  # 5 minute timeout
        )
        
        print("\n" + "=" * 70)
        
        if result.returncode == 0:
            print("✓ Repository cloned successfully!")
            thesis_exists = True
            
            # Show cloned directory size
            if os.path.exists(thesis_dir):
                size = subprocess.run(
                    ["du", "-sh", thesis_dir],
                    capture_output=True,
                    text=True
                )
                print(f"  Size: {size.stdout.split()[0] if size.stdout else 'Unknown'}")
        else:
            print("✗ Clone operation failed!")
            print("Tip: Check if your Fine-Grained token has 'Contents: Read' permission.")
            raise Exception("Git clone failed")
            
    except subprocess.TimeoutExpired:
        print("✗ Clone operation timed out (exceeded 5 minutes)")
        raise Exception("Clone operation timed out")
    except Exception as e:
        print(f"✗ Error during cloning: {str(e)}")
        print("\n⚠️  TROUBLESHOOTING:")
        print("  • Ensure 'Internet' is toggled ON in the Kaggle sidebar")
        print("  • Verify the Token is correct and hasn't expired")
        print("  • Ensure the Secret Label in Kaggle matches 'thesis-github-repo-secret'")
        raise
        
    print("=" * 70)
else:
    print("\n✓ Skipping clone - repository already exists locally")
# Out:
# 🌐 Cloning Private Thesis Repository from GitHub
# ======================================================================
# Repository: https://github.com/TAR2003/Thesis.git
# Destination: /kaggle/working
# ======================================================================
# ✓ Changed to working directory: /kaggle/working
#
# ⏳ Cloning in progress (Private Access enabled)...
# Cloning into 'Thesis'...
# remote: Enumerating objects: 665, done.
# remote: Counting objects: 100% (665/665), done.
# remote: Compressing objects: 100% (527/527), done.
# remote: Total 665 (delta 30), reused 600 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (665/665), 3.35 MiB | 11.67 MiB/s, done.
# Resolving deltas: 100% (30/30), done.
# ======================================================================
# ✓ Repository cloned successfully!
#   Size: 14M
# ======================================================================

# %% [markdown]
# ### Step 4: Verify and Navigate to time_complexity Folder
#
# Check that the time_complexity folder exists within the Thesis repository, then navigate into it for the remaining operations.

# %%
print("\n🗂️  Verifying time_complexity Folder")
print("=" * 70)

if os.path.exists(time_complexity_dir):
    print(f"✓ time_complexity folder found!")
    print(f"  Location: {time_complexity_dir}")
else:
    print(f"✗ time_complexity folder not found!")
    print(f"  Expected: {time_complexity_dir}")
    
    # List what's in thesis_dir to help debug
    print(f"\n📁 Contents of Thesis directory:")
    for item in os.listdir(thesis_dir):
        item_path = os.path.join(thesis_dir, item)
        if os.path.isdir(item_path):
            print(f"  📂 {item}/")
        else:
            print(f"  📄 {item}")
    
    raise Exception("time_complexity folder not found in Thesis repository")

# Navigate to time_complexity directory
os.chdir(time_complexity_dir)
print(f"\n✓ Changed working directory")
print(f"  Current location: {os.getcwd()}")
print("=" * 70)
# Out:
# 🗂️  Verifying time_complexity Folder
# ======================================================================
# ✓ time_complexity folder found!
#   Location: /kaggle/working/Thesis/time_complexity
#
# ✓ Changed working directory
#   Current location: /kaggle/working/Thesis/time_complexity
# ======================================================================

# %% [markdown]
# ### Step 5: Display Repository Contents
#
# List all files and folders in the time_complexity directory to verify the complete repository structure.

# %%
print("\n📋 Repository Contents of time_complexity/")
print("=" * 70)

contents_dirs = []
contents_files = []

for item in sorted(os.listdir(".")):
    item_path = os.path.join(".", item)
    if os.path.isdir(item_path):
        contents_dirs.append(item)
    else:
        contents_files.append(item)

# Display directories
if contents_dirs:
    print("📂 Directories:")
    for d in contents_dirs:
        size = len(os.listdir(d))
        print(f"  ├─ {d}/ ({size} items)")

# Display files
if contents_files:
    print("\n📄 Files:")
    for f in contents_files:
        size = os.path.getsize(f)
        size_str = f"{size / 1024:.1f} KB" if size > 1024 else f"{size} bytes"
        print(f"  ├─ {f} ({size_str})")

print("=" * 70)
print(f"✓ Repository ready! Found {len(contents_dirs)} directories and {len(contents_files)} files")
print("=" * 70)
# Out:
# 📋 Repository Contents of time_complexity/
# ======================================================================
# 📂 Directories:
#   ├─ graphs/ (9 items)
#   ├─ input/ (3 items)
#
# 📄 Files:
#   ├─ Edge.hpp (800 bytes)
#   ├─ FaceTriangulation.hpp (13.7 KB)
#   ├─ biconnected.hpp (3.1 KB)
#   ├─ input.txt (31 bytes)
#   ├─ main (389.2 KB)
#   ├─ main.cpp (31.2 KB)
#   ├─ main.exe (520.4 KB)
#   ├─ pairHash.hpp (459 bytes)
#   ├─ plot_results.py (8.1 KB)
#   ├─ results.csv (67.0 KB)
#   ├─ results.html (6.0 KB)
#   ├─ results.txt (11.2 KB)
# ======================================================================
# ✓ Repository ready! Found 2 directories and 12 files
# ======================================================================

# %% [markdown]
# ## 3. Build & Compilation
#
# ---
#
# ### Step 1: Verify Build Requirements
#
# Check that all necessary source files exist before compilation.

# %%
print("\n📝 Checking Build Requirements")
print("=" * 70)

required_files = ["main.cpp"]
missing_files = []

for file in required_files:
    if os.path.exists(file):
        size = os.path.getsize(file)
        print(f"  ✓ {file} found ({size} bytes)")
    else:
        print(f"  ✗ {file} NOT found")
        missing_files.append(file)

if missing_files:
    print(f"\n✗ Missing {len(missing_files)} required file(s)!")
    raise Exception(f"Missing files: {', '.join(missing_files)}")
else:
    print(f"\n✓ All required files are present")

print("=" * 70)
# Out:
# 📝 Checking Build Requirements
# ======================================================================
#   ✓ main.cpp found (31988 bytes)
#
# ✓ All required files are present
# ======================================================================

# %% [markdown]
# ### Step 2: Compile C++ Code with Optimizations
#
# Compile the main.cpp source file using g++ with O3 optimization flag for maximum performance during benchmarking.

# %%
print("\n🔨 C++ Compilation")
print("=" * 70)

compiler = "g++"
source_file = "main.cpp"
output_binary = "triangulation_benchmark"
optimization = "-O3"

print(f"Compiler: {compiler}")
print(f"Source: {source_file}")
print(f"Optimization: {optimization}")
print(f"Output: {output_binary}")
print("\n⏳ Compilation in progress...")
print("=" * 70)

try:
    start_time = datetime.now()
    
    result = subprocess.run(
        [compiler, optimization, source_file, "-o", output_binary],
        capture_output=True,
        text=True,
        timeout=60
    )
    
    end_time = datetime.now()
    compile_time = (end_time - start_time).total_seconds()
    
    print(f"\n✓ Compilation completed in {compile_time:.2f} seconds")
    
    if result.returncode == 0:
        # Check binary exists and get size
        if os.path.exists(output_binary):
            binary_size = os.path.getsize(output_binary)
            print(f"✓ Binary created successfully")
            print(f"  → Filename: {output_binary}")
            print(f"  → Size: {binary_size / 1024 / 1024:.2f} MB")
            print(f"  → Permissions: ", end="")
            result_stat = subprocess.run(["ls", "-lh", output_binary], 
                                        capture_output=True, text=True)
            print(result_stat.stdout.split()[-1])
        else:
            raise Exception("Binary file was not created")
    else:
        print(f"✗ Compilation failed!")
        print(f"\nCompiler output:\n{result.stderr}")
        raise Exception("Compilation failed with errors")
        
except subprocess.TimeoutExpired:
    print("✗ Compilation timed out (exceeded 60 seconds)")
    raise Exception("Compilation timeout")
except Exception as e:
    print(f"✗ Error: {str(e)}")
    raise

print("=" * 70)
# Out:
# 🔨 C++ Compilation
# ======================================================================
# Compiler: g++
# Source: main.cpp
# Optimization: -O3
# Output: triangulation_benchmark
#
# ⏳ Compilation in progress...
# ======================================================================
#
# ✓ Compilation completed in 4.79 seconds
# ✓ Binary created successfully
#   → Filename: triangulation_benchmark
#   → Size: 0.12 MB
#   → Permissions: triangulation_benchmark
# ======================================================================

# %% [markdown]
# ## 4. Benchmarking Execution
#
# ---
#
# ### Step 1: Pre-execution Verification
#
# Verify that the compiled binary exists and is executable before starting the benchmark.

# %%
print("\n✅ Pre-Execution Verification")
print("=" * 70)

binary_name = "triangulation_benchmark"

if os.path.exists(binary_name):
    # Check if it's executable
    if os.access(binary_name, os.X_OK):
        size = os.path.getsize(binary_name)
        print(f"✓ Binary is ready for execution")
        print(f"  → Filename: {binary_name}")
        print(f"  → Size: {size / 1024 / 1024:.2f} MB")
        print(f"  → Executable: Yes")
    else:
        print(f"⚠ Binary exists but is not executable, fixing...")
        os.chmod(binary_name, os.stat(binary_name).st_mode | 0o111)
        print(f"✓ Binary is now executable")
else:
    print(f"✗ Binary not found: {binary_name}")
    raise Exception("Compiled binary not found. Please run compilation step first.")

print("\n✓ Ready to execute benchmarks")
print("=" * 70)
# Out:
# ✅ Pre-Execution Verification
# ======================================================================
# ✓ Binary is ready for execution
#   → Filename: triangulation_benchmark
#   → Size: 0.12 MB
#   → Executable: Yes
#
# ✓ Ready to execute benchmarks
# ======================================================================

# %% [markdown]
# ### Step 2: Run Benchmark with Real-Time Output
#
# Execute the triangulation benchmark. The program will process all test cases and write results to results.csv as each test completes. You'll see real-time progress output below.

# %%
import subprocess
import sys

try:
    # Use Popen for real-time streaming to the console
    process = subprocess.Popen(
        ["stdbuf", "-oL", "./triangulation_benchmark"],
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        bufsize=1  # Line buffered
    )

    # Print output as it happens
    for line in process.stdout:
        print(line, end='', flush=True)

    process.wait()
    exit_code = process.returncode
    
    end_time = datetime.now()
    # ... rest of your timing code ...

    if exit_code == 0:
        print("\n✓ Benchmark execution completed successfully!")
    else:
        print(f"\n⚠ Benchmark finished with exit code: {exit_code}")

except Exception as e:
    print(f"\n✗ Error during benchmark execution: {str(e)}")
# Out:
# ╔════════════════════════════════════════════════════════════════════════════╗
# ║          TRIANGULATION BENCHMARK - Time & Space Complexity Analysis       ║
# ╚════════════════════════════════════════════════════════════════════════════╝
#
# Scanning folder: input/small
# Test runs per file: 10
#
# ⇢ Skipping already-processed file: C04_square_cycle.txt
# ⇢ Skipping already-processed file: C05_pentagon_cycle.txt
# ⇢ Skipping already-processed file: C06_hexagon_cycle_1.txt
# ⇢ Skipping already-processed file: C07_heptagon_cycle.txt
# ⇢ Skipping already-processed file: C08_octagon_cycle.txt
# ⇢ Skipping already-processed file: C09_nonagon_cycle.txt
# ⇢ Skipping already-processed file: C10_decagon_cycle.txt
# ⇢ Skipping already-processed file: W5_wheel_2.txt
# ⇢ Skipping already-processed file: complex.txt
# ⇢ Skipping already-processed file: graph_V11F3.txt
# ⇢ Skipping already-processed file: graph_V12E25F12.txt
# ⇢ Skipping already-processed file: graph_V6E7F3_1.txt
# ⇢ Skipping already-processed file: graph_V6E7F3_2.txt
# ⇢ Skipping already-processed file: graph_V6E7F3_3.txt
# ⇢ Skipping already-processed file: graph_V6E7F3_4.txt
# ⇢ Skipping already-processed file: graph_V7E11F5.txt
# ⇢ Skipping already-processed file: graph_V7E9F3.txt
# ⇢ Skipping already-processed file: graph_V7F3_theta_a1_b1_c3_T392_v1.txt
# ⇢ Skipping already-processed file: graph_V7F3_theta_a1_b1_c3_T392_v2.txt
# ⇢ Skipping already-processed file: graph_V7F3_theta_a1_b1_c3_T392_v3.txt
# ⇢ Skipping already-processed file: graph_V7F3_theta_a1_b2_c2_T350_v1.txt
# ⇢ Skipping already-processed file: graph_V7F3_theta_a1_b2_c2_T350_v2.txt
# ⇢ Skipping already-processed file: graph_V7F3_theta_a1_b2_c2_T350_v3.txt
# ⇢ Skipping already-processed file: graph_V7F3_theta_a1_b3_c1_T392_v1.txt
# ⇢ Skipping already-processed file: graph_V7F3_theta_a1_b3_c1_T392_v2.txt
# ⇢ Skipping already-processed file: graph_V7F3_theta_a1_b3_c1_T392_v3.txt
# ⇢ Skipping already-processed file: graph_V7F3_theta_a2_b1_c2_T350_v1.txt
# ⇢ Skipping already-processed file: graph_V7F3_theta_a2_b1_c2_T350_v2.txt
# ⇢ Skipping already-processed file: graph_V7F3_theta_a2_b1_c2_T350_v3.txt
# ⇢ Skipping already-processed file: graph_V7F3_theta_a2_b2_c1_T350_v1.txt
# ⇢ Skipping already-processed file: graph_V7F3_theta_a2_b2_c1_T350_v2.txt
# ⇢ Skipping already-processed file: graph_V7F3_theta_a2_b2_c1_T350_v3.txt
# ⇢ Skipping already-processed file: graph_V7F3_theta_a3_b1_c1_T392_v1.txt
# ⇢ Skipping already-processed file: graph_V7F3_theta_a3_b1_c1_T392_v2.txt
# ⇢ Skipping already-processed file: graph_V7F3_theta_a3_b1_c1_T392_v3.txt
# ⇢ Skipping already-processed file: graph_V8E10F4.txt
# ⇢ Skipping already-processed file: graph_V8E15F8.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a1_b1_c4_T3528_v1.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a1_b1_c4_T3528_v2.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a1_b1_c4_T3528_v3.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a1_b2_c3_T2940_v1.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a1_b2_c3_T2940_v2.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a1_b2_c3_T2940_v3.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a1_b3_c2_T2940_v1.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a1_b3_c2_T2940_v2.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a1_b3_c2_T2940_v3.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a1_b4_c1_T3528_v1.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a1_b4_c1_T3528_v2.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a1_b4_c1_T3528_v3.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a2_b1_c3_T2940_v1.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a2_b1_c3_T2940_v2.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a2_b1_c3_T2940_v3.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a2_b2_c2_T2744_v1.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a2_b2_c2_T2744_v2.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a2_b2_c2_T2744_v3.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a2_b3_c1_T2940_v1.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a2_b3_c1_T2940_v2.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a2_b3_c1_T2940_v3.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a3_b1_c2_T2940_v1.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a3_b1_c2_T2940_v2.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a3_b1_c2_T2940_v3.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a3_b2_c1_T2940_v1.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a3_b2_c1_T2940_v2.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a3_b2_c1_T2940_v3.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a4_b1_c1_T3528_v1.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a4_b1_c1_T3528_v2.txt
# ⇢ Skipping already-processed file: graph_V8F3_theta_a4_b1_c1_T3528_v3.txt
# ⇢ Skipping already-processed file: graph_V9E10F3.txt
# ⇢ Skipping already-processed file: quadrilateral_14quad.txt
# ⇢ Skipping already-processed file: quadrilateral_4quad.txt
# ⇢ Skipping already-processed file: quadrilateral_7quad.txt
# ⇢ Skipping already-processed file: simple3.txt
# ⇢ Skipping already-processed file: square7.txt
# ⇢ Skipping already-processed file: square8.txt
# ⇢ Skipping already-processed file: square_with_pentagon.txt
# ⇢ Skipping already-processed file: trople_rectangle.txt
#
# ╔════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╗
# ║                                                    BENCHMARK RESULTS                                                               ║
# ╠═══════════════════════════╦════════════╦═════════════════╦══════════════╦═══════════════╦═════════════════╦════════════════════════╣
# ║ File                     ║   Vertices║       Triangulations║     Time (s)║        ns/Triang║     Peak Memory║          Memory/Vertex║
# ╠═══════════════════════════╬════════════╬═════════════════╬══════════════╬═══════════════╬═════════════════╬════════════════════════╣
# ║ C04_square_cycle.txt     ║          4║                    2║     0.000003║       1.4010e+03║          0.00 B║                 0.00 B║
# ║ C05_pentagon_cycle.txt   ║          5║                   10║     0.000009║       9.2700e+02║         8.00 KB║                1.60 KB║
# ║ C06_hexagon_cycle_1.txt  ║          6║                   68║     0.000096║       1.4060e+03║         4.00 KB║               682.00 B║
# ║ C07_heptagon_cycle.txt   ║          7║                  546║     0.000414║       7.5800e+02║         8.00 KB║                1.14 KB║
# ║ C08_octagon_cycle.txt    ║          8║                 4872║     0.003040║       6.2400e+02║         4.00 KB║               512.00 B║
# ║ C09_nonagon_cycle.txt    ║          9║                46782║     0.025897║       5.5400e+02║         4.00 KB║               455.00 B║
# ║ C10_decagon_cycle.txt    ║         10║               474180║     0.257996║       5.4400e+02║         4.00 KB║               409.00 B║
# ║ W5_wheel_2.txt           ║          6║                    5║     0.000006║       1.1400e+03║         4.00 KB║               682.00 B║
# ║ complex.txt              ║         13║              1282136║     0.596025║       4.6500e+02║         8.00 KB║               630.00 B║
# ║ graph_V11F3.txt          ║         11║               672902║     0.343786║       5.1100e+02║         4.00 KB║               372.00 B║
# ║ graph_V12E25F12.txt      ║         12║                   62║     0.000032║       5.0900e+02║         8.00 KB║               682.00 B║
# ║ graph_V6E7F3_1.txt       ║          6║                   20║     0.000023║       1.1270e+03║         4.00 KB║               682.00 B║
# ║ graph_V6E7F3_2.txt       ║          6║                   24║     0.000024║       1.0110e+03║         4.00 KB║               682.00 B║
# ║ graph_V6E7F3_3.txt       ║          6║                   20║     0.000034║       1.7050e+03║         8.00 KB║                1.33 KB║
# ║ graph_V6E7F3_4.txt       ║          6║                   20║     0.000020║       9.7700e+02║         8.00 KB║                1.33 KB║
# ║ graph_V7E11F5.txt        ║          7║                    7║     0.000012║       1.6500e+03║         8.00 KB║                1.14 KB║
# ║ graph_V7E9F3.txt         ║          7║                    9║     0.000007║       7.9100e+02║         4.00 KB║               585.00 B║
# ║ graph_V8E10F4.txt        ║          8║                   40║     0.000034║       8.5000e+02║         8.00 KB║                1.00 KB║
# ║ graph_V8E15F8.txt        ║          8║                    5║     0.000004║       8.7500e+02║         8.00 KB║                1.00 KB║
# ║ graph_V9E10F3.txt        ║          9║                13880║     0.009591║       6.9100e+02║         8.00 KB║               910.00 B║
# ║ quadrilateral_14quad.txt ║         16║                16384║     0.010510║       6.4100e+02║         8.00 KB║               512.00 B║
# ║ quadrilateral_4quad.txt  ║          9║                   16║     0.000011║       6.8900e+02║         4.00 KB║               455.00 B║
# ║ quadrilateral_7quad.txt  ║          9║                   72║     0.000057║       7.8800e+02║         4.00 KB║               455.00 B║
# ║ simple3.txt              ║          5║                    4║     0.000005║       1.2140e+03║         4.00 KB║               819.00 B║
# ║ square7.txt              ║          9║                   36║     0.000040║       1.1200e+03║         8.00 KB║               910.00 B║
# ║ square8.txt              ║         10║                   48║     0.000048║       9.9300e+02║         8.00 KB║               819.00 B║
# ║ square_with_pentagon.txt ║          5║                    4║     0.000006║       1.6040e+03║         4.00 KB║               819.00 B║
# ║ trople_rectangle.txt     ║          5║                    4║     0.000005║       1.2410e+03║         4.00 KB║               819.00 B║
# ║ C11_cycle.txt            ║         11║              5010456║     2.733858║       5.4600e+02║          0.00 B║                 0.00 B║
# ║ graph_V13F4.txt          ║         13║              9568244║     4.438180║       4.6400e+02║          0.00 B║                 0.00 B║
# ║ graph_V13F4_version_2.txt║         13║             10225274║     4.537475║       4.4400e+02║          0.00 B║                 0.00 B║
# ║ grid_4x4.txt             ║         16║              4613504║     1.884005║       4.0800e+02║          0.00 B║                 0.00 B║
# ║ C12_cycle.txt            ║         12║             54721224║    25.280202║       4.6200e+02║          0.00 B║                 0.00 B║
# ║ C13_cycle.txt            ║         13║            613912182║   262.822566║       4.2800e+02║          0.00 B║                 0.00 B║
# ║ C14_cycle.txt            ║         14║           7042779996║  3064.941383║       4.3500e+02║          0.00 B║                 0.00 B║
# ║ graph_V15F5.txt          ║         15║             89897864║    40.054776║       4.4600e+02║          0.00 B║                 0.00 B║
# ║ graph_V18F6.txt          ║         18║           7932840664║  3637.362618║       4.5900e+02║          0.00 B║                 0.00 B║
# ║ grid_5x5.txt             ║         25║             81920000║    46.257442║       5.6500e+02║          0.00 B║                 0.00 B║
# ║ C15_cycle.txt            ║         15║          82329308040║ 26861.404167║       3.2600e+02║          0.00 B║                 0.00 B║
# ║ graph_V11F3_theta_a1_b1_c║         11║               997586║     0.368788║       3.7000e+02║          0.00 B║                 0.00 B║
# ║ graph_V11F3_theta_a1_b1_c║         11║               997586║     0.397080║       3.9800e+02║          0.00 B║                 0.00 B║
# ║ graph_V11F3_theta_a1_b1_c║         11║               997586║     0.398393║       3.9900e+02║         4.00 KB║               372.00 B║
# ║ graph_V11F3_theta_a1_b2_c║         11║               795998║     0.278418║       3.5000e+02║         4.00 KB║               372.00 B║
# ║ graph_V11F3_theta_a1_b2_c║         11║               795998║     0.284381║       3.5700e+02║         4.00 KB║               372.00 B║
# ║ graph_V11F3_theta_a1_
+02║         4.00 KB║               455.00 B║
# ║ graph_V9F3_theta_a3_b3_c1║          9║                 8460║     0.004458║       5.2700e+02║         4.00 KB║               455.00 B║
# ║ graph_V9F3_theta_a3_b3_c1║          9║                 8460║     0.004724║       5.5800e+02║         4.00 KB║               455.00 B║
# ║ graph_V9F3_theta_a3_b3_c1║          9║                 8460║     0.004373║       5.1700e+02║         4.00 KB║               455.00 B║
# ║ graph_V9F3_theta_a4_b1_c2║          9║                 8922║     0.004439║       4.9800e+02║          0.00 B║                 0.00 B║
# ║ graph_V9F3_theta_a4_b1_c2║          9║                 8922║     0.004764║       5.3400e+02║          0.00 B║                 0.00 B║
# ║ graph_V9F3_theta_a4_b1_c2║          9║                 8922║     0.004570║       5.1200e+02║          0.00 B║                 0.00 B║
# ║ graph_V9F3_theta_a4_b2_c1║          9║                 8922║     0.005019║       5.6300e+02║          0.00 B║                 0.00 B║
# ║ graph_V9F3_theta_a4_b2_c1║          9║                 8922║     0.004295║       4.8100e+02║          0.00 B║                 0.00 B║
# ║ graph_V9F3_theta_a4_b2_c1║          9║                 8922║     0.004029║       4.5200e+02║          0.00 B║                 0.00 B║
# ║ graph_V9F3_theta_a5_b1_c1║          9║                10478║     0.005772║       5.5100e+02║          0.00 B║                 0.00 B║
# ║ graph_V9F3_theta_a5_b1_c1║          9║                10478║     0.005105║       4.8700e+02║          0.00 B║                 0.00 B║
# ║ graph_V9F3_theta_a5_b1_c1║          9║                10478║     0.005053║       4.8200e+02║         4.00 KB║               455.00 B║

# %% [markdown]
# ## 5. Results Analysis
#
# ---
#
# ### Step 1: Verify Results Files
#
# Check which output files were generated by the benchmark program.

# %%
print("\n📁 Checking Generated Output Files")
print("=" * 70)

output_files = {
    "results.csv": "CSV - Results table",
    "results.txt": "Text - Readable results",
    "results.html": "HTML - Interactive report"
}

found_files = {}
total_size = 0

for filename, description in output_files.items():
    if os.path.exists(filename):
        file_size = os.path.getsize(filename)
        found_files[filename] = file_size
        total_size += file_size
        print(f"✓ {filename}")
        print(f"  → {description}")
        print(f"  → Size: {file_size / 1024:.1f} KB")
    else:
        print(f"✗ {filename} (not found)")

print("\n" + "-" * 70)
if found_files:
    print(f"✓ Successfully generated {len(found_files)} file(s)")
    print(f"  Total size: {total_size / 1024 / 1024:.2f} MB")
else:
    print(f"⚠ No output files found - benchmark may not have completed")

print("=" * 70)

# %% [markdown]
# ### Step 2: Display Benchmark Results from CSV
#
# The results.csv file contains all benchmark data written incrementally during test execution. Each row represents one test case with timing measurements.

# %%
print("\n📊 Benchmark Results Summary")
print("=" * 70)

csv_file = "results.csv"

if os.path.exists(csv_file):
    try:
        with open(csv_file, "r") as f:
            csv_content = f.read()
        
        lines = csv_content.strip().split('\n')
        print(f"✓ results.csv loaded ({len(lines)} lines)\n")
        
        # Display header and first few rows
        print("📈 CSV Contents:")
        print("-" * 70)
        
        for i, line in enumerate(lines):
            if len(line) > 150:
                # Truncate very long lines for readability
                print(line[:147] + "...")
            else:
                print(line)
            
            # Add separator after header
            if i == 0:
                print("-" * 70)
            
            # Limit display to first 30 rows
            if i >= 29:
                remaining = len(lines) - i - 1
                if remaining > 0:
                    print(f"... and {remaining} more rows")
                break
        
        print("-" * 70)
        
    except Exception as e:
        print(f"✗ Error reading results.csv: {str(e)}")
else:
    print(f"✗ results.csv not found")
    print(f"  → Benchmark may not have completed successfully")
    print(f"  → Check the benchmark execution output above for errors")

print("=" * 70)

# %% [markdown]
# ### Step 3: Final Summary
#
# Summary of the entire benchmarking pipeline execution.

# %%
print("\n🎉 Benchmarking Pipeline Complete!")
print("=" * 70)

pipeline_steps = [
    ("1. Environment Setup", "✓"),
    ("2. Repository Setup", "✓"),
    ("3. Build & Compilation", "✓"),
    ("4. Benchmarking Execution", "✓"),
    ("5. Results Analysis", "✓")
]

print("Pipeline Execution Summary:\n")
for step, status in pipeline_steps:
    print(f"  {status} {step}")

print("\n" + "-" * 70)
print(f"✓ All steps completed successfully!")
print(f"  Working directory: {os.getcwd()}")
print(f"  Completion time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print("=" * 70)

print("\n📋 Next Steps:")
print("  • Review results.csv for detailed benchmark data")
print("  • Check results.txt for formatted output")
print("  • Open results.html in a browser for interactive visualization")
print("  • Results are saved in:", os.getcwd())
print("\n✓ Notebook execution finished!")
print("=" * 70)

# %% [markdown]
# # Use this one for fresh run

# %%
# !rm -rf /kaggle/working/Thesis

# %%
# !lscpu
# Out:
# Architecture:                x86_64
#   CPU op-mode(s):            32-bit, 64-bit
#   Address sizes:             46 bits physical, 48 bits virtual
#   Byte Order:                Little Endian
# CPU(s):                      4
#   On-line CPU(s) list:       0-3
# Vendor ID:                   GenuineIntel
#   Model name:                Intel(R) Xeon(R) CPU @ 2.20GHz
#     CPU family:              6
#     Model:                   79
#     Thread(s) per core:      2
#     Core(s) per socket:      2
#     Socket(s):               1
#     Stepping:                0
#     BogoMIPS:                4399.99
#     Flags:                   fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pg
#                              e mca cmov pat pse36 clflush mmx fxsr sse sse2 ss h
#                              t syscall nx pdpe1gb rdtscp lm constant_tsc rep_goo
#                              d nopl xtopology nonstop_tsc cpuid tsc_known_freq p
#                              ni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2ap
#                              ic movbe popcnt aes xsave avx f16c rdrand hyperviso
#                              r lahf_lm abm 3dnowprefetch pti ssbd ibrs ibpb stib
#                              p fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms
#                              invpcid rtm rdseed adx smap xsaveopt arat md_clear
#                              arch_capabilities
# Virtualization features:
#   Hypervisor vendor:         KVM
#   Virtualization type:       full
# Caches (sum of all):
#   L1d:                       64 KiB (2 instances)
#   L1i:                       64 KiB (2 instances)
#   L2:                        512 KiB (2 instances)
#   L3:                        55 MiB (1 instance)
# NUMA:
#   NUMA node(s):              1
#   NUMA node0 CPU(s):         0-3
# Vulnerabilities:
#   Gather data sampling:      Not affected
#   Indirect target selection: Mitigation; Aligned branch/return thunks
#   Itlb multihit:             Not affected
#   L1tf:                      Mitigation; PTE Inversion
#   Mds:                       Mitigation; Clear CPU buffers; SMT Host state unkno
#                              wn
#   Meltdown:                  Mitigation; PTI
#   Mmio stale data:           Vulnerable: Clear CPU buffers attempted, no microco
#                              de; SMT Host state unknown
#   Reg file data sampling:    Not affected
#   Retbleed:                  Mitigation; IBRS
#   Spec rstack overflow:      Not affected
#   Spec store bypass:         Mitigation; Speculative Store Bypass disabled via p
#                              rctl
#   Spectre v1:                Mitigation; usercopy/swapgs barriers and __user poi
#                              nter sanitization
#   Spectre v2:                Mitigation; IBRS; IBPB conditional; STIBP condition
#                              al; RSB filling; PBRSB-eIBRS Not affected; BHI SW l
#                              oop, KVM SW loop
#   Srbds:                     Not affected
#   Tsa:                       Not affected
#   Tsx async abort:           Mitigation; Clear CPU buffers; SMT Host state unkno
#                              wn
#   Vmscape:                   Not affected
